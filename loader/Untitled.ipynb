# %%
import pandas as pd

# %%
warfarin_df = pd.read_csv("../data/warfarin.csv")
warfarin_df
# Out:
#      PharmGKB Subject ID  Gender                       Race  \
# 0            PA135312261    male                      White
# 1            PA135312262  female                      White
# 2            PA135312263  female                      White
# 3            PA135312264    male                      White
# 4            PA135312265    male                      White
# 5            PA135312266    male                      White
# 6            PA135312267    male                      White
# 7            PA135312268    male                      White
# 8            PA135312269  female                      White
# 9            PA135312270    male                      White
# 10           PA135312271    male                      White
# 11           PA135312272  female                      White
# 12           PA135312273    male                      White
# 13           PA135312274  female                      White
# 14           PA135312275    male                      White
# ...

# %%
import rl-warfarin.utils.python_utilities as python_utilities
# Out:
#   File "<ipython-input-8-ed2e0d04e9d2>", line 1
#     import rl-warfarin.utils.python_utilities as python_utilities
#              ^
# SyntaxError: invalid syntax
